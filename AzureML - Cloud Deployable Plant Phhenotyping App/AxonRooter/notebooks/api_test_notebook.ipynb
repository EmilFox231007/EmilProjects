# %%
import requests

# The URL of the API
api_url = 'http://localhost:8000/'
endpoint = 'predict/'
url = api_url + endpoint

# Create the payload
payload = {'path_to_img': r"C:\Users\batkm\Desktop\Year2BlockD\data\test1.png"}

# Send the POST request
response = requests.post(url, json=payload)

# Print the response
print(response.json())
